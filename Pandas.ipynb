# %%
import pandas as pd
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
# print(type(iris))
df = iris.copy()
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']

# %%
df.head(3) # row = 3 by default shows five
print(df.shape)
# Out:
# (149, 5)

# %%
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_type'], dtype='object')

# %%
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']

# %%
print(df.shape)
df.dtypes
# Out:
# (149, 5)
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.sl # df["sl"]
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
df.iloc[1:4,2:3]
# Out:
#     pl
# 1  1.3
# 2  1.5
# 3  1.4

# %%
a = df.drop(0)
df.head()
a.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df.drop(3,inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.index # index label
# Out:
# Int64Index([  1,   2,   4,   5,   6,   7,   8,   9,  10,  11,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=147)

# %%
df.index[0], df.index[3] # index
# Out:
# (1, 5)

# %%
df.drop(df.index[[0,1]], inplace=True) # 0th row and 1st row
df.head()
# Out:
#      sl   sw   pl   pw  flower_type
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa

# %%
df.sl>5 # boolean array
df[df.sl>5]
# Out:
#       sl   sw   pl   pw     flower_type
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [116 rows x 5 columns]

# %%
df[df.flower_type=='Iris-setosa']
# Out:
#      sl   sw   pl   pw  flower_type
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa
# 20  5.1  3.7  1.5  0.4  Iris-setosa
# 21  4.6  3.6  1.0  0.2  Iris-setosa
# 22  5.1  3.3  1.7  0.5  Iris-setosa
# 23  4.8  3.4  1.9  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa
# 25  5.0  3.4  1.6  0.4  Iris-setosa
# 26  5.2  3.5  1.5  0.2  Iris-setosa
# 27  5.2  3.4  1.4  0.2  Iris-setosa
# 28  4.7  3.2  1.6  0.2  Iris-setosa
# 29  4.8  3.1  1.6  0.2  Iris-setosa
# 30  5.4  3.4  1.5  0.4  Iris-setosa
# 31  5.2  4.1  1.5  0.1  Iris-setosa
# 32  5.5  4.2  1.4  0.2  Iris-setosa
# ...

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  141.000000  141.000000  141.000000  141.000000
# mean     5.906383    3.036170    3.906383    1.260284
# std      0.810927    0.434787    1.716484    0.745547
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.200000    2.800000    1.600000    0.400000
# 50%      5.800000    3.000000    4.500000    1.400000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# Add row
print(df.head())
print(df.iloc[0]) # doing it by position
print(df.loc[8]) # doing it by label
# Out:
#      sl   sw   pl   pw  flower_type
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# sl                     4.9
# sw                     3.1
# pl                     1.5
# pw                     0.1
# flower_type    Iris-setosa
# Name: 8, dtype: object
# sl                     4.9
# sw                     3.1
# pl                     1.5
# pw                     0.1
# flower_type    Iris-setosa
# Name: 8, dtype: object

# %%
df.loc[0] = [1,2,3,4,"Iris-setosa"]

# %%
df.head()
# Out:
#      sl   sw   pl   pw  flower_type
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa

# %%
# reset index
df = iris.copy()
df = df.reset_index(drop = True, inplace = True)
df

# %%
df = iris.copy()
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']
news = df[df.flower_type=='Iris-setosa']
print(news.describe())
news = df[df.flower_type=='Iris-versicolor']
print(news.describe())
# Out:
#               sl         sw         pl         pw
# count  49.000000  49.000000  49.000000  49.000000
# mean    5.004082   3.416327   1.465306   0.244898
# std     0.355879   0.384787   0.175061   0.108130
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.100000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000
#               sl         sw         pl         pw
# count  50.000000  50.000000  50.000000  50.000000
# mean    5.936000   2.770000   4.260000   1.326000
# std     0.516171   0.313798   0.469911   0.197753
# min     4.900000   2.000000   3.000000   1.000000
# 25%     5.600000   2.525000   4.000000   1.200000
# 50%     5.900000   2.800000   4.350000   1.300000
# 75%     6.300000   3.000000   4.600000   1.500000
# max     7.000000   3.400000   5.100000   1.800000

# %%
df["diff_pl_pw"] = df["pl"] - df["pw"]
df.tail()
df = iris.copy()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3

# %%
import numpy as np
df.iloc[2:4,1:3] = np.nan 
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  NaN  NaN  0.2  Iris-setosa
# 3  5.0  NaN  NaN  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.sw.fillna(df.sw.mean(),inplace = True)
df.head()
df.pl.fillna(df.pl.mean(), inplace = True)
df.head()
# Out:
#     sl        sw        pl   pw  flower_type
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa
# 2  4.6  3.046939  3.806122  0.2  Iris-setosa
# 3  5.0  3.046939  3.806122  0.2  Iris-setosa
# 4  5.4  3.900000  1.700000  0.4  Iris-setosa

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  147.000000  147.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369
# std      0.828594    0.434048    1.750351    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.dropna(inplace = True)
df.head()
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df["Gender"] = "Female"
df.head()
df.iloc[:10,5] = "Male"
df.head()
df.tail()
def f(s):
    if s=="Male":
        return 0
    return 1
df["sex"] = df.Gender.apply(f)
df.head()
df.tail()
del df["Gender"]
df.head()
# Out:
#     sl        sw        pl   pw  flower_type  sex
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa    0
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa    0
# 2  4.6  3.046939  3.806122  0.2  Iris-setosa    0
# 3  5.0  3.046939  3.806122  0.2  Iris-setosa    0
# 4  5.4  3.900000  1.700000  0.4  Iris-setosa    0
