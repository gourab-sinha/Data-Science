# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path = '/Users/gourabsinha/Desktop/Data Science/Packages/chromedriver')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="2ea132557774fe28db7fcbe02d7ac2d8")>

# %%
driver.get('https://www.codingninjas.com')

# %%
driver.title
# Out:
# "Practice & Learn Coding Online at India's Best Coding Courses - Coding Ninjas"

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('SC_TEST.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en"><head>\n  <meta charset="utf-8">\n  <title>Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas</title>\n\n  <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n  <meta name="title" content="Coding Ninjas">\n  <meta property="og:title" content="Practice &amp; Learn Coding Online at India\'s Best Coding Courses - Coding Ninjas">\n  <meta name="description" content="Practice Coding Online at Coding Ninjas which is  India\'s best Programming and software training institute that offers courses in Java, C++, Android, Data Structure, Web Development, Ruby on Rails and more. Registration open for Online Coding Classes and offline Coding Classes in Delhi.">\n  <meta property="og:description" content="Practice Coding Online at Coding Ninjas which is  India\'s best Programming and software training institute that offers courses in Java, C++, Android, Data Structure, Web Development, Ruby on Rails and more.
# ...

# %%
reg_btn = driver.find_element_by_link_text('Register')
reg_btn.click()

# %%
driver.find_element_by_partial_link_text('Reg')
reg_btn.click()

# %%
# if not found will give error
link = 'https://codezen.codingninjas.in/dashboard?_ga=2.50188646.1150794502.1583264754-473959317.1562489169'
driver.get(link)

# %%
adv_btn = driver.find_element_by_partial_link_text('Advanced')
adv_btn.click()

# %%
driver.get('https://www.google.com/')
mage_btn = driver.find_element_by_partial_link_text('mage')
mage_btn.click()

# %%
driver.title
# Out:
# 'Google Images'

# %%
driver.back()

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.close() # only the current is closed
# driver.quit() close the driver object

# %%
driver = webdriver.Chrome(executable_path = '/Users/gourabsinha/Desktop/Data Science/Packages/chromedriver')
driver.get('http://books.toscrape.com/')

# %%
m_btn = driver.find_element_by_link_text('Music')
m_btn.click()

# %%
b1 = driver.find_element_by_partial_link_text('Kill')
b1.click() # only first link

# %%
i1 = driver.find_element_by_class_name('image_container')
i1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="66bc7c24-9d68-400e-934f-bc18f647d0ce")>

# %%
i1.click()

# %%
driver.back()

# %%
i1 = driver.find_elements_by_class_name('image_container')
i1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="1862fc7a-d0e4-4fc1-bcd6-d1977747935c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="65157608-a25a-4dd7-817a-2f0e9a4c7854")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="13fe4ffc-46ed-469f-97a0-fde2bdf798a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="c9f62902-7743-4d6e-9711-acb7a4776a24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="8036ac4d-08c2-4bb1-b948-02417cb491c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="e680b692-ad52-4e9d-aa32-85054526d3fa")>,
# ...

# %%
len(i1)
# Out:
# 13

# %%
driver.find_element_by_tag_name('img')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="8b4f283b-7d45-4d27-bdc2-30471acbf4ba")>

# %%
driver.find_element_by_name('viewport')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="8939105f-b662-41a8-acf8-8a48e29d9194")>

# %%
driver.get('https://codingninjas.in/courses?_ga=2.208607698.1150794502.1583264754-473959317.1562489169')

# %%
driver.find_element_by_tag_name('img')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="eee905085bbe4fc2cff9e40770466430", element="d654d06e-0ada-4c95-903b-cd246c5c6a82")>

# %%
driver.close()

# %%
driver = webdriver.Chrome(executable_path = '/Users/gourabsinha/Desktop/Data Science/Packages/chromedriver')
driver.get('http://books.toscrape.com/')

# %%
m_btn = driver.find_element_by_link_text('Music')
m_btn.click()

# %%
i1 = driver.find_element_by_class_name('image_container')
print(type(i1)) # clickable it will click otherwise nothing will happen
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>

# %%
# clear if it is user_editable. .click
# get_attribute(name)  get the attr 
# is_displayed() for pop_button return True/False
# is_enabled to check enable button or not. return True/False
# is_selected() radio button / check button. return True/False
# text is to get the text
# tag_name to get the tag name.

# %%
driver.get('https://www.facebook.com/r.php')
firstname = driver.find_element_by_name('firstname')
firstname.is_enabled()
# Out:
# True

# %%
female = driver.find_element_by_class_name('_58mt')
female.is_enabled()
# Out:
# True

# %%
# xpath
driver.get('http://books.toscrape.com/')
ans = driver.find_element_by_xpath(('/html/head/title'))

# %%
ans.get_attribute('outerHTML') # html part
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans.get_attribute('innerHTML') # excluding the tag
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
ans = driver.find_element_by_xpath('/html/body/div/div/ul')
ans.get_attribute('outerHTML')
# Out:
# '<ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>'

# %%
# relative path

ans = driver.find_element_by_xpath('//ul[@class = "breadcrumb"]')
ans
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2ea132557774fe28db7fcbe02d7ac2d8", element="ac836c9a-9f56-4ebb-9518-1523ad7d467f")>

# %%
ans = driver.find_elements_by_xpath('//ul') # all ul tags
ans
#
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ea132557774fe28db7fcbe02d7ac2d8", element="ac836c9a-9f56-4ebb-9518-1523ad7d467f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ea132557774fe28db7fcbe02d7ac2d8", element="2c8d9b13-5827-424e-864f-180d113a5bd3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ea132557774fe28db7fcbe02d7ac2d8", element="3c492c52-5173-45cf-81c3-a9ff05c720ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ea132557774fe28db7fcbe02d7ac2d8", element="724a4c49-24d8-4cea-aa96-12960af672fc")>]

# %%
driver.get('https://www.nga.gov/collection/artists.html')
